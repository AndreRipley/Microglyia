# %%
import os, io
import pandas as pd
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\andre\\Desktop\\MicroglyiaAI'

# %%
mouseData = pd.read_csv("testData3.csv")
mouseData.head()
# Out:
#    Time(s)     Test1     Test2     Test3     Test4     Test5     Test6  \
# 0    0.000  0.000680  0.008623  0.025172 -0.003751 -0.007400  0.003724
# 1    0.051 -0.001976  0.007450  0.026128  0.000917 -0.006743  0.003340
# 2    0.102 -0.000397  0.012649  0.025768 -0.002301 -0.007570  0.002447
# 3    0.153  0.000393  0.012207  0.027159 -0.001118 -0.008118  0.002481
# 4    0.204  0.000538  0.013739  0.025403 -0.000213 -0.007199  0.005354
#
#       Test7     Test8     Test9    Test10    Test11    Test12    Test13  \
# 0  0.006715  0.000261  0.017465 -0.000680  0.002521  0.004307  0.009294
# 1  0.008885 -0.001490  0.020015 -0.001833  0.002667  0.004074  0.005321
# 2  0.008273 -0.000544  0.020800 -0.001632 -0.000188  0.003424  0.006657
# 3  0.009223 -0.004383  0.019174 -0.003319 -0.000266  0.003712  0.006089
# 4  0.008351 -0.001941  0.020977 -0.000684 -0.000131  0.003483  0.008369
#
#      Test14
# 0  0.011635
# 1  0.010806
# 2  0.010797
# 3  0.010511
# 4  0.012354

# %%
mouseData.tail()
# Out:
#       Time(s)     Test1     Test2     Test3     Test4     Test5     Test6  \
# 2765  141.015 -0.013692 -0.010918 -0.006797  0.002036  0.017256 -0.001046
# 2766  141.066 -0.012662 -0.006198 -0.008190  0.002787  0.019331  0.000415
# 2767  141.117 -0.015189 -0.003471 -0.007987 -0.001878  0.020514 -0.000987
# 2768  141.168 -0.013936 -0.007532 -0.006830 -0.001225  0.018659 -0.000410
# 2769  141.219 -0.015484 -0.004738 -0.008233 -0.000973  0.017298 -0.000999
#
#          Test7     Test8     Test9    Test10    Test11    Test12    Test13  \
# 2765 -0.007846 -0.004320 -0.015580 -0.001534 -0.006377 -0.000208 -0.015849
# 2766 -0.006790  0.001012 -0.018498  0.001062 -0.000331 -0.005449 -0.014420
# 2767 -0.006237 -0.001943 -0.014079 -0.007342 -0.001289 -0.005444 -0.013266
# 2768 -0.005515 -0.001969 -0.018304 -0.004700  0.000013 -0.006114 -0.013535
# 2769 -0.005669 -0.001668 -0.017326 -0.001602  0.001042 -0.003707 -0.012321
#
#         Test14
# 2765  0.013206
# 2766  0.014711
# 2767  0.013312
# ...

# %%
cols = mouseData.columns
print(cols)
# Out:
# Index(['Time(s)', 'Test1', 'Test2', 'Test3', 'Test4', 'Test5', 'Test6',
#        'Test7', 'Test8', 'Test9', 'Test10', 'Test11', 'Test12', 'Test13',
#        'Test14'],
#       dtype='object')

# %%
mouseData.shape
# Out:
# (2770, 15)

# %%
mouseData.isnull().values.any()
# Out:
# True

# %%
#Data with respect to time.
mouseData.plot(y="Test1", x="Time(s)")
mouseData.plot(y="Test2", x="Time(s)")
mouseData.plot(y="Test3", x="Time(s)")
mouseData.plot(y="Test4", x="Time(s)")
mouseData.plot(y="Test5", x="Time(s)")
mouseData.plot(y="Test6", x="Time(s)")
mouseData.plot(y="Test7", x="Time(s)")
mouseData.plot(y="Test8", x="Time(s)")
mouseData.plot(y="Test9", x="Time(s)")
mouseData.plot(y="Test10", x="Time(s)")
mouseData.plot(y="Test11", x="Time(s)")
mouseData.plot(y="Test12", x="Time(s)")
mouseData.plot(y="Test13", x="Time(s)")

# %%
#Get correlations of each features in dataset
corrmat = mouseData.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(mouseData[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#Mouse Data correlation dataframe
mouseData.corr()
# Out:
#           Time(s)     Test1     Test2     Test3     Test4     Test5     Test6  \
# Time(s)  1.000000 -0.450570 -0.751531 -0.560239 -0.146258  0.703256 -0.170803
# Test1   -0.450570  1.000000  0.350578 -0.103367  0.294095 -0.727322 -0.119174
# Test2   -0.751531  0.350578  1.000000  0.190881  0.413147 -0.588213  0.110152
# Test3   -0.560239 -0.103367  0.190881  1.000000 -0.421137 -0.116085  0.330549
# Test4   -0.146258  0.294095  0.413147 -0.421137  1.000000 -0.420706 -0.097488
# Test5    0.703256 -0.727322 -0.588213 -0.116085 -0.420706  1.000000 -0.007022
# Test6   -0.170803 -0.119174  0.110152  0.330549 -0.097488 -0.007022  1.000000
# Test7   -0.922426  0.396520  0.705083  0.496565  0.202619 -0.701393  0.195755
# Test8    0.453137  0.170249 -0.349780 -0.455782  0.257240 -0.058361 -0.289498
# Test9   -0.925327  0.372703  0.752027  0.499617  0.260260 -0.672530  0.157562
# Test10  -0.156568  0.243463  0.345452 -0.251504  0.505922 -0.382909 -0.024052
# ...
